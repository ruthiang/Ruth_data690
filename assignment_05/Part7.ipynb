# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthiang/Ruth_data690/blob/main/assignment_05/Part7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 7
# ## 3/3/22
# ## Ruth Iang

# %% [markdown]
# ### Reading CSV and TXT files

# %%
import pandas as pd

# %%
filepath = 'btc-market-price.csv'

with open(filepath, 'r') as reader:
    print(reader)
# Out:
# <_io.TextIOWrapper name='btc-market-price.csv' mode='r' encoding='UTF-8'>

# %%
filepath = 'btc-market-price.csv'

with open(filepath, 'r') as reader:
    for index, line in enumerate(reader.readlines()):
        # read just the first 10 lines
        if (index < 10):
            print(index, line)
# Out:
# 0 2/4/17 0:00,1099.169125
#
# 1 3/4/17 0:00,1141.813
#
# 2 4/4/17 0:00,?
#
# 3 5/4/17 0:00,1133.079314
#
# 4 6/4/17 0:00,-
#
# 5 7/4/17 0:00,-
#
# 6 8/4/17 0:00,1181.149838
#
# 7 9/4/17 0:00,1208.8005
#
# 8 10/4/17 0:00,1207.744875
#
# 9 11/4/17 0:00,1226.617038

# %% [markdown]
# ### The most common parameters

# %%
# filepath: Path of the file to be read.
# sep: Character(s) that are used as a field separator in the file.
# header: Index of the row containing the names of the columns (None if none).
# index_col: Index of the column or sequence of indexes that should be used as index of rows of the data.
# names: Sequence containing the names of the columns (used together with header = None).
# skiprows: Number of rows or sequence of row indexes to ignore in the load.
# na_values: Sequence of values that, if found in the file, should be treated as NaN.
# dtype: Dictionary in which the keys will be column names and the values will be types of NumPy to which their content must be converted.
# parse_dates: Flag that indicates if Python should try to parse data with a format similar to dates as dates. You can enter a list of column names that must be joined for the parsing as a date.
# date_parser: Function to use to try to parse dates.
# nrows: Number of rows to read from the beginning of the file.
# skip_footer: Number of rows to ignore at the end of the file.
# encoding: Encoding to be expected from the file read.
# squeeze: Flag that indicates that if the data read only contains one column the result is a Series instead of a DataFrame.
# thousands: Character to use to detect the thousands separator.
# decimal: Character to use to detect the decimal separator.
# skip_blank_lines: Flag that indicates whether blank lines should be ignored.

# %% [markdown]
# ### Reading our first CSV file
# - Everytime we call read_csv method, we'll need to pass an explicit filepath parameter indicating the path where our CSV file is
# - Valid URL schemes include HTTP, FTP, S3, and file
# - For file URLs, a host is expected. A local file could be: file://localhost/path/to/table.csv.

# %%
csv_url = "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"

pd.read_csv(csv_url).head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df = pd.read_csv('btc-market-price.csv')

df.head()
# Out:
#    2/4/17 0:00  1099.169125
# 0  3/4/17 0:00     1141.813
# 1  4/4/17 0:00            ?
# 2  5/4/17 0:00  1133.079314
# 3  6/4/17 0:00            -
# 4  7/4/17 0:00            -

# %% [markdown]
# ###  First row behaviour with header parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None)

# %%
df.head()
# Out:
#              0            1
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00     1141.813
# 2  4/4/17 0:00            ?
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00            -

# %% [markdown]
# ###  Missing values with na_values parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'])

# %%
df.head()
# Out:
#              0            1
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %% [markdown]
# ###  Column names using names parameter
# - We can define a na_values parameter with the values we want to be recognized as NA/NaN. In this case empty strings '', ? and - will be recognized as null values

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'])

# %%
df.head()
# Out:
#      Timestamp        Price
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %% [markdown]
# ### Column types using dtype parameter
# - We can use dtype parameter to force pandas to use certain dtype b/c it will try to figure it each type of column automatically

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'})

# %%
df.head()
# Out:
#      Timestamp        Price
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df.dtypes    #object means regular string
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()    #using to_datetime method to change to datetime
# Out:
# 0   2017-02-04
# 1   2017-03-04
# 2   2017-04-04
# 3   2017-05-04
# 4   2017-06-04
# Name: Timestamp, dtype: datetime64[ns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %% [markdown]
# ### Date parser using parse_dates parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %% [markdown]
# ### Adding index to our data using index_col parameter
# - It takes a numeric value representing the index or a string of the column name for setting a single column as index or a list of numeric values or strings for creating a multi-index
# - can use index_col to override property of column to index

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0],
                 index_col=[0])

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-02-04  1099.169125
# 2017-03-04  1141.813000
# 2017-04-04          NaN
# 2017-05-04  1133.079314
# 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Price    float64
# dtype: object

# %% [markdown]
# ### A more challenging parsing

# %%
exam_df = pd.read_csv('exam_review.csv')

# %%
exam_df
# Out:
#                                first_name>last_name>age>math_score>french_score
# Ray>Morley>18>"68     000">"75                                             000"
# Melvin>Scott>24>77>83 NaN                                                   NaN
# Amirah>Haley>22>92>67 NaN                                                   NaN
# Gerard>Mills>19>"78   000">72                                               NaN
# Amy>Grimes>23>91>81   NaN                                                   NaN

# %% [markdown]
# ### Custom data delimiters using sep parameter
# - We can define which delimiter to use by using the sep parameter or pandas will automatically detect the separator
# - most csv files separator will be , and it will be detected automatically. But we can find files with other separators like semicolon (;), tabs (\t, specially on TSV files), whitespaces or any other special character.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %% [markdown]
# ###  Custom data encoding
# - While reading data custom encoding can be defined with the encoding parameter.
#
#       - encoding='UTF-8': will be used if data is UTF-8 encoded.
#       - encoding='iso-8859-1': will be used if data is ISO/IEC 8859-1    ("extended ASCII") encoded.

# %% [markdown]
# ### Custom numeric decimal and thousands character
# -  If we have a column containing a comma (,) to indicate the decimal or thousands place, then this column would be considered a string and not numeric.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>')
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      object
# french_score    object
# dtype: object

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',')
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      float64
# french_score    float64
# dtype: object

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            thousands=',')
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18       68000         75000
# 1     Melvin     Scott   24          77            83
# 2     Amirah     Haley   22          92            67
# 3     Gerard     Mills   19       78000            72
# 4        Amy    Grimes   23          91            81

# %% [markdown]
# ### Excluding specific rows
# - Exclude reading specified number of rows from the beginning of a file, by passing an integer argument. This removes the header too.
# - Skip reading specific row indices from a file, by passing a list containing row indices to skip.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',')
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            skiprows=2)
# To skip reading the first 2 rows from this file, we can use skiprows=2:
# Out:
#    Melvin   Scott  24      77  83
# 0  Amirah   Haley  22      92  67
# 1  Gerard   Mills  19  78,000  72
# 2     Amy  Grimes  23      91  81

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',',
                      skiprows=[1,3])
exam_df

# As the header is considered as the first row
# to skip reading data rows 1 and 3, we can use skiprows=[1,3]:
# Out:
#   first_name last_name  age  math_score  french_score
# 0     Melvin     Scott   24        77.0            83
# 1     Gerard     Mills   19        78.0            72
# 2        Amy    Grimes   23        91.0            81

# %% [markdown]
# ### Get rid of blank files
# - The skip_blank_lines parameter is set to True so blank lines are skipped while we read files.
# - If we set this parameter to False, then every blank line will be loaded with NaN values into the DataFrame.

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            skip_blank_lines=False)
# Out:
#   first_name last_name   age math_score french_score
# 0        Ray    Morley  18.0     68,000       75,000
# 1     Melvin     Scott  24.0         77           83
# 2     Amirah     Haley  22.0         92           67
# 3        NaN       NaN   NaN        NaN          NaN
# 4     Gerard     Mills  19.0     78,000           72
# 5        Amy    Grimes  23.0         91           81

# %% [markdown]
# ### Loading specific columns
# - As a parameter to usecols, you can pass either a list of strings corresponding to the column names or a list of integers corresponding to column index.

# %%
pd.read_csv('exam_review.csv',
            usecols=['first_name', 'last_name', 'age'],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
pd.read_csv('exam_review.csv',
            usecols=[0, 1, 2],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %% [markdown]
# ### Using a Series instead of Dataframe
# - If the parsed data only contains one column then we can return a Series by setting the squeeze parameter to True

# %%
exam_test_1 = pd.read_csv('exam_review.csv',
                          sep='>',
                          usecols=['last_name'])

# %%
type(exam_test_1)
# Out:
# pandas.core.frame.DataFrame

# %%
exam_test_2 = pd.read_csv('exam_review.csv',
                          sep='>',
                          usecols=['last_name'],
                          squeeze=True)

type(exam_test_2)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Save to CSV file

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0     Melvin     Scott   24        77.0            83
# 1     Gerard     Mills   19        78.0            72
# 2        Amy    Grimes   23        91.0            81

# %%
exam_df.to_csv()
# We can simply generate a CSV string from our DataFrame
# Out:
# ',first_name,last_name,age,math_score,french_score\n0,Melvin,Scott,24,77.0,83\n1,Gerard,Mills,19,78.0,72\n2,Amy,Grimes,23,91.0,81\n'

# %%
exam_df.to_csv('out.csv')

# %%
pd.read_csv('out.csv')
# Out:
#    Unnamed: 0 first_name last_name  age  math_score  french_score
# 0           0     Melvin     Scott   24        77.0            83
# 1           1     Gerard     Mills   19        78.0            72
# 2           2        Amy    Grimes   23        91.0            81

# %%
exam_df.to_csv('out.csv',
               index=None)

# %%
pd.read_csv('out.csv')
# Out:
#   first_name last_name  age  math_score  french_score
# 0     Melvin     Scott   24        77.0            83
# 1     Gerard     Mills   19        78.0            72
# 2        Amy    Grimes   23        91.0            81

# %% [markdown]
# ### Using SQL method

# %%
import sqlite3

# %%
conn = sqlite3.connect("chinook.db")

# %%
cur = conn.cursor()
# the cursor created has a method exercise, which will receive SQL paramenter to run against the database
# The code below will fetch has the first 5 rows from the employees table

# %%
cur.execute("SELECT * FROM employees LIMIT 5;")
# we can use fetchall method to fetch all of the results of a query

# %%
results = cur.fetchall()

# %%
results
# the results are returned as a list of tuples
# Each tuples corresponds to a row in the database that we accessed
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5G3',
#   '+1 (403) 263-4423',
#   '+1 (403) 263-4289',
#   'margaret@chinookcorp.com'),
#  (5,
#   'Johnson',
#   'Steve',
#   'Sales Support Agent',
#   2,
#   '1965-03-03 00:00:00',
#   '2003-10-17 00:00:00',
#   '7727B 41 Ave',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 1Y7',
#   '1 (780) 836-9987',
#   '1 (780) 836-9543',
#   'steve@chinookcorp.com')]

# %%
df = pd.DataFrame(results)

# %%
df.head()
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
cur.close()
conn.close()

# %% [markdown]
# ### Using pandas read_sql method
# - we can use the pandas read-sql function to read the results of a SQL query directly into a pandas DataFrame. The code below will execute the same query that we just did, but it will return a DataFrame. It has several advantages over the query we did above:
#  - it doesnt require use to create a cursor object or call fetchall at the end
#  -it automatically reads in the names of the headers from the table
#  - it creates a DataFrame, so we can quickly explore the data

# %%
conn = sqlite3.connect("chinook.db")

# %%
df = pd.read_sql("SELECT * FROM employees;", conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql ("SELECT * FROM employees;",conn, index_col= "EmployeeId",parse_dates = ["Birthdate", "HireDate"])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN
# 2           Edwards     Nancy        Sales Manager        1.0
# 3           Peacock      Jane  Sales Support Agent        2.0
# 4              Park  Margaret  Sales Support Agent        2.0
# 5           Johnson     Steve  Sales Support Agent        2.0
#
#                       BirthDate   HireDate              Address      City  \
# EmployeeId
# 1           1962-02-18 00:00:00 2002-08-14  11120 Jasper Ave NW  Edmonton
# 2           1958-12-08 00:00:00 2002-05-01         825 8 Ave SW   Calgary
# 3           1973-08-29 00:00:00 2002-04-01        1111 6 Ave SW   Calgary
# 4           1947-09-19 00:00:00 2003-05-03     683 10 Street SW   Calgary
# 5           1965-03-03 00:00:00 2003-10-17         7727B 41 Ave   Calgary
#
#            State Country PostalCode              Phone                Fax  \
# EmployeeId
# 1             AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 2             AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 3             AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 4             AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 5             AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                                Email
# EmployeeId
# 1             andrew@chinookcorp.com
# 2              nancy@chinookcorp.com
# 3               jane@chinookcorp.com
# 4           margaret@chinookcorp.com
# 5              steve@chinookcorp.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      object
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      object
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: datetime64[ns](1), float64(1), object(12)
# memory usage: 960.0+ bytes

# %%
df["ReportsTo"].isna().sum()
# Out:
# 1

# %%
df["ReportsTo"].mean()
# Out:
# 2.857142857142857

# %%
df["ReportsTo"] > 1.75
# Out:
# EmployeeId
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# Name: ReportsTo, dtype: bool

# %%
df ["City"] = df["City"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      object
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      category
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: category(1), datetime64[ns](1), float64(1), object(11)
# memory usage: 1.0+ KB

# %% [markdown]
# ### Using pandas read_sql_query method

# %%
conn = sqlite3.connect("chinook.db")

# %%
df = pd.read_sql_query("SELECT * FROM employees LIMIT 5;", conn)

# %%
df. head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql ("SELECT * FROM employees;",conn, index_col= "EmployeeId",parse_dates = ["Birthdate", "HireDate"])

# %% [markdown]
# ### Using read_sql_table method
# - read_sql_table is a useful function, but it only works with SQL alchemy, a Pythong SQL Toolkit and Object Relational Mapper

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///chinook.db")
connection = engine.connect()

# %%
df = pd.read_sql_table ("employees", con = connection)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
connection.close()

# %% [markdown]
# ### Create tables from DataFrame object
# - we can persist DataFrame objects, we have working on in a database using the pandas to_sql method.It is easy to implement, but it could be a very slow process.

# %%
df.head()   # drop the table if needed
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df.to_sql?

# %%
cur = conn.cursor()

# %%
cur.execute("DROP TABLE IF EXISTS employees2;")

# %%
cur.close()

# %%
df.to_sql("employees2", conn)    #what table name is going to be and a connection object

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    index  EmployeeId LastName FirstName                Title  ReportsTo  \
# 0      0           1    Adams    Andrew      General Manager        NaN
# 1      1           2  Edwards     Nancy        Sales Manager        1.0
# 2      2           3  Peacock      Jane  Sales Support Agent        2.0
# 3      3           4     Park  Margaret  Sales Support Agent        2.0
# 4      4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
#pd.read_sql_query('DROP TABLE employees2;', conn)

# %% [markdown]
# ### Custom behaviour
# - The if_exists parameter define how to behave if the table already exists and adds a ton of flexibility, letting you decide wheather to replace current database data, append new data at the end, or simply fail if database already exists

# %%
pd.DataFrame().to_sql('employees2',
                      conn,
                      if_exists='replace')

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
df.to_sql('employees2',
          conn,
          if_exists='replace')

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    index  EmployeeId LastName FirstName                Title  ReportsTo  \
# 0      0           1    Adams    Andrew      General Manager        NaN
# 1      1           2  Edwards     Nancy        Sales Manager        1.0
# 2      2           3  Peacock      Jane  Sales Support Agent        2.0
# 3      3           4     Park  Margaret  Sales Support Agent        2.0
# 4      4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
conn.close()
