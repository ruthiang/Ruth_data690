# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthiang/Ruth_data690/blob/main/in_class_wdx_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA_URL = "https://raw.githubusercontent.com/wcj365/jay_data690/main/wdi_data_2000_2020.csv"

config_dict = {'editable': True, 
                'edits' : {'titleText': True, 
                           "axisTitleText": True,
                           'annotationText' : True, 
                           'annotationPosition' : True,
                           "shapePosition": True,
                           'legendPosition' : True,
                           'legendText' : False},
               'modeBarButtonsToAdd':['drawline',
                                      'drawopenpath',
                                      'drawclosedpath',
                                      'drawcircle',
                                      'drawrect',
                                      'eraseshape'],
               'toImageButtonOptions' : {'scale' : 2}
              }

# %%
df = pd.read_csv(DATA_URL)

df.head()
# Out:
#    Unnamed: 0  Year       value    indicator Country Code Country Name  \
# 0           0  2000  20779957.0  SP.POP.TOTL          AFG  Afghanistan
# 1           1  2001  21606992.0  SP.POP.TOTL          AFG  Afghanistan
# 2           2  2002  22600774.0  SP.POP.TOTL          AFG  Afghanistan
# 3           3  2003  23680871.0  SP.POP.TOTL          AFG  Afghanistan
# 4           4  2004  24726689.0  SP.POP.TOTL          AFG  Afghanistan
#
#        Region Income Group Lending Type
# 0  South Asia   Low income          IDA
# 1  South Asia   Low income          IDA
# 2  South Asia   Low income          IDA
# 3  South Asia   Low income          IDA
# 4  South Asia   Low income          IDA

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

df.tail()
# Out:
#        Year  value       indicator Country Code Country Name  \
# 16253  2015   18.0  SH.STA.SUIC.P5          ZWE     Zimbabwe
# 16254  2016   16.8  SH.STA.SUIC.P5          ZWE     Zimbabwe
# 16255  2017   15.0  SH.STA.SUIC.P5          ZWE     Zimbabwe
# 16256  2018   14.0  SH.STA.SUIC.P5          ZWE     Zimbabwe
# 16257  2019   14.1  SH.STA.SUIC.P5          ZWE     Zimbabwe
#
#                     Region         Income Group Lending Type
# 16253  Sub-Saharan Africa   Lower middle income        Blend
# 16254  Sub-Saharan Africa   Lower middle income        Blend
# 16255  Sub-Saharan Africa   Lower middle income        Blend
# 16256  Sub-Saharan Africa   Lower middle income        Blend
# 16257  Sub-Saharan Africa   Lower middle income        Blend

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16258 entries, 0 to 16257
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          16258 non-null  int64
#  1   value         16258 non-null  float64
#  2   indicator     16258 non-null  object
#  3   Country Code  16258 non-null  object
#  4   Country Name  16258 non-null  object
#  5   Region        16258 non-null  object
#  6   Income Group  16258 non-null  object
#  7   Lending Type  16258 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1016.2+ KB

# %%
df_2019 = df.query("Year == 2019")
df_2019.head()
# Out:
#      Year       value    indicator Country Code    Country Name  \
# 19   2019  38041757.0  SP.POP.TOTL          AFG     Afghanistan
# 40   2019   2854191.0  SP.POP.TOTL          ALB         Albania
# 61   2019  43053054.0  SP.POP.TOTL          DZA         Algeria
# 82   2019     55312.0  SP.POP.TOTL          ASM  American Samoa
# 103  2019     77146.0  SP.POP.TOTL          AND         Andorra
#
#                          Region         Income Group    Lending Type
# 19                   South Asia           Low income             IDA
# 40        Europe & Central Asia  Upper middle income            IBRD
# 61   Middle East & North Africa  Lower middle income            IBRD
# 82          East Asia & Pacific  Upper middle income  Not classified
# 103       Europe & Central Asia          High income  Not classified

# %%
df_2019_pivot = df_2019.pivot_table(index=["Year", "Country Code", "Country Name", "Region", "Income Group", "Lending Type"], 
                                    columns="indicator", values="value")
df_2019_pivot.head()
# Out:
# indicator                                                                                     NY.GDP.PCAP.PP.CD  \
# Year Country Code Country Name Region                     Income Group        Lending Type
# 2019 ABW          Aruba        Latin America & Caribbean  High income         Not classified                NaN
#      AFG          Afghanistan  South Asia                 Low income          IDA                   2152.366489
#      AGO          Angola       Sub-Saharan Africa         Lower middle income IBRD                  6952.419362
#      ALB          Albania      Europe & Central Asia      Upper middle income IBRD                 14012.976435
#      AND          Andorra      Europe & Central Asia      High income         Not classified                NaN
#
# indicator                                                                                     SH.STA.SUIC.P5  \
# Year Country Code Country Name Region                     Income Group        Lending Type
# 2019 ABW          Aruba        Latin America & Caribbean  High income         Not classified             NaN
#      AFG          Afghanistan  South Asia                 Low income          IDA                        4.1
#      AGO          Angola       Sub-Saharan Africa         Lower middle income IBRD                       6.1
#      ALB          Albania      Europe & Central Asia      Upper middle income IBRD                       4.3
#      AND          Andorra      Europe & Central Asia      High income         Not classified             NaN
#
# indicator                                                                                     SP.DYN.LE00.IN  \
# Year Country Code Country Name Region                     Income Group        Lending Type
# 2019 ABW          Aruba        Latin America & Caribbean  High income         Not classified          76.293
#      AFG          Afghanistan  South Asia                 Low income          IDA                     64.833
#      AGO          Angola       Sub-Saharan Africa         Lower middle income IBRD                    61.147
#      ALB          Albania      Europe & Central Asia      Upper middle income IBRD                    78.573
#      AND          Andorra      Europe & Central Asia      High income         Not classified             NaN
#
# indicator                                                                                     SP.POP.TOTL
# Year Country Code Country Name Region                     Income Group        Lending Type
# 2019 ABW          Aruba        Latin America & Caribbean  High income         Not classified     106310.0
#      AFG          Afghanistan  South Asia                 Low income          IDA              38041757.0
#      AGO          Angola       Sub-Saharan Africa         Lower middle income IBRD             31825299.0
#      ALB          Albania      Europe & Central Asia      Upper middle income IBRD              2854191.0
#      AND          Andorra      Europe & Central Asia      High income         Not classified      77146.0

# %%
df_2019_pivot = df_2019_pivot.reset_index()

df_2019_pivot.head()
# Out:
# indicator  Year Country Code Country Name                      Region  \
# 0          2019          ABW        Aruba  Latin America & Caribbean
# 1          2019          AFG  Afghanistan                  South Asia
# 2          2019          AGO       Angola         Sub-Saharan Africa
# 3          2019          ALB      Albania       Europe & Central Asia
# 4          2019          AND      Andorra       Europe & Central Asia
#
# indicator         Income Group    Lending Type  NY.GDP.PCAP.PP.CD  \
# 0                  High income  Not classified                NaN
# 1                   Low income             IDA        2152.366489
# 2          Lower middle income            IBRD        6952.419362
# 3          Upper middle income            IBRD       14012.976435
# 4                  High income  Not classified                NaN
#
# indicator  SH.STA.SUIC.P5  SP.DYN.LE00.IN  SP.POP.TOTL
# 0                     NaN          76.293     106310.0
# 1                     4.1          64.833   38041757.0
# 2                     6.1          61.147   31825299.0
# 3                     4.3          78.573    2854191.0
# 4                     NaN             NaN      77146.0

# %%
df_2019_pivot.shape
# Out:
# (217, 10)

# %%
df_2019_pivot[df_2019_pivot.isna().any(axis=1)]
# Out:
# indicator  Year Country Code               Country Name  \
# 0          2019          ABW                      Aruba
# 4          2019          AND                    Andorra
# 8          2019          ASM             American Samoa
# 24         2019          BMU                    Bermuda
# 34         2019          CHI            Channel Islands
# 45         2019          CUB                       Cuba
# 46         2019          CUW                    Curacao
# 47         2019          CYM             Cayman Islands
# 0                        NaN             NaN       76.293000     106310.0
# 4                        NaN             NaN             NaN      77146.0
# 8                        NaN             NaN             NaN      55312.0
# 24              85263.763003             NaN       81.866585      63913.0
# 34                       NaN             NaN       83.086000     172264.0
# 45                       NaN            14.5       78.802000   11333484.0
# 46              25530.206866             NaN             NaN     157441.0
# 47              76747.666306             NaN             NaN      64948.0
# 52              12892.021100             NaN             NaN      71808.0
# 58                       NaN            10.9       66.321000          NaN
# 65                       NaN             NaN       82.746341      48677.0
# 71                       NaN             NaN             NaN      33706.0
# 78                       NaN             NaN             NaN      56225.0
# 80                       NaN             NaN       80.074000     167295.0
# 82              62106.100881             NaN       85.078049    7507400.0
# 88                       NaN             NaN             NaN      84589.0
# 104             29812.595002             NaN             NaN      52834.0
# 112                      NaN             NaN       83.041463      38020.0
# 118            132654.896700             NaN       84.244000     640446.0
# 119                      NaN             NaN       79.973171      38002.0
# 121                      NaN             NaN             NaN      38967.0
# 126              4219.793440             NaN             NaN      58791.0
# 133                      NaN             NaN             NaN      57213.0
# 140                      NaN             NaN       77.634146     271300.0
# 147             14099.485354             NaN             NaN      10764.0
# 154             17957.767739             NaN             NaN      18001.0
# 157             36276.842361             NaN       79.928512    3193694.0
# 158                      NaN             9.4       72.274000   25666158.0
# 161              6509.568335             NaN       74.053000    4685306.0
# 162                      NaN             NaN       77.657000     279285.0
# 174             63420.327135             NaN             NaN      33864.0
# 177                      NaN             3.9       57.846000   11062114.0
# 184                      NaN             NaN             NaN      40733.0
# 186                      NaN             2.0       72.697000   17070132.0
# 187             30488.105168             NaN             NaN      38194.0
# 198              4455.542635             NaN             NaN      11655.0
# 206                      NaN             2.1       72.064000   28515829.0
# 207                      NaN             NaN             NaN      30033.0
# 208                      NaN             NaN       79.668293     106669.0
# 212             11797.119317             NaN       72.495122    1788878.0
# 213                      NaN             5.8       66.125000   29161922.0

# %%
df_2019_pivot.dropna(inplace=True)

df_2019_pivot.head()
# Out:
# indicator  Year Country Code          Country Name  \
# 1          2019          AFG           Afghanistan
# 2          2019          AGO                Angola
# 3          2019          ALB               Albania
# 5          2019          ARE  United Arab Emirates
# 6          2019          ARG             Argentina
#
# indicator                      Region         Income Group    Lending Type  \
# 1                          South Asia           Low income             IDA
# 2                 Sub-Saharan Africa   Lower middle income            IBRD
# 3               Europe & Central Asia  Upper middle income            IBRD
# 5          Middle East & North Africa          High income  Not classified
# 6          Latin America & Caribbean   Upper middle income            IBRD
#
# indicator  NY.GDP.PCAP.PP.CD  SH.STA.SUIC.P5  SP.DYN.LE00.IN  SP.POP.TOTL
# 1                2152.366489             4.1          64.833   38041757.0
# 2                6952.419362             6.1          61.147   31825299.0
# 3               14012.976435             4.3          78.573    2854191.0
# 5               71150.542141             6.4          77.972    9770526.0
# 6               22999.275053             8.4          76.667   44938712.0

# %%
df_2019_pivot.shape
# Out:
# (176, 10)

# %%
fig = px.scatter(df_2019_pivot[df_2019_pivot["Region"] == "South Asia"], 
                 x="NY.GDP.PCAP.PP.CD", 
                 y="SP.DYN.LE00.IN",
                 size = "SP.POP.TOTL",
                 size_max = 100,
                 text="Country Code",
                 height = 800,
                 width = 600,
                 hover_name = "Country Name",
                 template = list(plotly.io.templates.keys())[6],
                 labels={"NY.GDP.PCAP.PP.CD":"2019 GDP per Capita","SP.DYN.LE00.IN":"2019 Life Expectancy"},
                 title="Wealth vs Health for South Asia",
                 color="Region")
fig.update_traces(textposition='middle right')   #tells us where the label should be
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e7310330-10ce-43b7-8502-f4fa34e50cc5" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7310330-10ce-43b7-8502-f4fa34e50cc5")) {                    Plotly.newPlot(                        "e7310330-10ce-43b7-8502-f4fa34e50cc5",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Region=South Asia<br>2019 GDP per Capita=%{x}<br>2019 Life Expectancy=%{y}<br>SP.POP.TOTL=%{marker.size}<br>Country Code=%{text}<extra></extra>","hovertext":["Afghanistan","Bangladesh","Bhutan","India","Sri Lanka","Maldives","Nepal","Pakistan"],"legendgroup":"South Asia","marker":{"color":"#1F77B4","size":[38041757.0,163046173.0,763094.0,1366417756.0,21803000.0,530957.0,28608715.0,216565317.0],"sizemode":"area","sizeref":136641.7756,"symbol":"circle"},"mode":"markers+text","name":"South Asia","orientation":"v","showlegend":true,"text":["AFG","BGD","BTN","IND","LKA","MDV","NPL","PAK"],"x":[2152.3664894209,4954.7618481258,12366.526476148,6997.8639882408,13622.8604484357,20335.5893322004,4119.9223393551,4896.3931450617],"xaxis":"x","y":[64.833,72.591,71.777,69.656,76.978,78.921,70.778,67.273],"yaxis":"y","type":"scatter","textposition":"middle right"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"2019 GDP per Capita"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"2019 Life Expectancy"}},"legend":{"title":{"text":"Region"},"tracegroupgap":0,"itemsizing":"constant"},"title":{"text":"Wealth vs Health for South Asia"},"height":800,"width":600},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('e7310330-10ce-43b7-8502-f4fa34e50cc5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
list(plotly.io.templates.keys())[0]
# Out:
# 'ggplot2'

# %%
list(plotly.io.templates.keys())
# Out:
# ['ggplot2',
#  'seaborn',
#  'simple_white',
#  'plotly',
#  'plotly_white',
#  'plotly_dark',
#  'presentation',
#  'xgridoff',
#  'ygridoff',
#  'gridon',
#  'none']

# %%
fig = px.pie (df_2019_pivot, 
              values = "SP.POP.TOTL", 
              names= "Country Name",
              height = 800, 
              title= "Population of the World" )
fig.update_traces(textposition = "inside", textinfo = "label+text+value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a4bd4c46-68b8-4fcc-a8f1-6cb0176faa82" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4bd4c46-68b8-4fcc-a8f1-6cb0176faa82")) {                    Plotly.newPlot(                        "a4bd4c46-68b8-4fcc-a8f1-6cb0176faa82",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"