# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthiang/Ruth_data690/blob/main/assignment_03/help_for_hw03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In Class Practice
# ## Date: 02/14/22

# %%
x = [2,5,12,"jay", "wang"]

print(x)
# Out:
# [2, 5, 12, 'jay', 'wang']

# %%
for a in x:
  print(a, end = " * ")
# Out:
# 2 * 5 * 12 * jay * wang *

# %%
5 in x
# Out:
# True

# %%
if 5 in x:
    print("5 is a member of a list x.")
else:
    print("5 is not a member of a list x")
# Out:
# 5 is a member of a list x.

# %%
y = [5,1,5,6,2,7,8,6,4,2]
print(y)
# Out:
# [5, 1, 5, 6, 2, 7, 8, 6, 4, 2]

# %%
for b in y:
  print(b, end=" ")
# Out:
# 5 1 5 6 2 7 8 6 4 2

# %%
for b in y:
  print(b)
# Out:
# 5
# 1
# 5
# 6
# 2
# 7
# 8
# 6
# 4
# 2

# %%
import random

# %%
random.randint(0,9)
#random number between 2 and 10
# Out:
# 4

# %%
for i in range(10):
#0-9
  print(random.randint(0,9), end= " ")
# Out:
# 1 0 9 2 6 1 6 1 6 3

# %%
for j in range(10):
  for i in range(10):
      print(random.randint(0,9), end= " ")
 #1. print("\n", end="")
  print("")
# Out:
# 5 1 8 9 3 6 0 7 6 3
# 0 8 1 6 3 5 5 6 0 4
# 5 8 9 7 5 1 9 8 5 1
# 2 4 2 2 9 3 2 4 5 1
# 6 3 4 8 1 4 3 2 0 8
# 7 5 9 5 0 4 2 3 3 6
# 9 0 6 6 0 0 0 3 7 4
# 8 8 0 0 6 2 4 4 2 2
# 7 2 5 6 1 4 3 8 9 7
# 5 3 1 6 8 4 8 5 5 2
